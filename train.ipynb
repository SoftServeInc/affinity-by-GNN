# %%
import torch
import torch.nn as nn

from affinity_module.config import get_config

import numpy as np

from dgllife.utils import EarlyStopping

from affinity_module.utils import set_random_seed, load_model
from affinity_module.utils import run_a_train_epoch, run_stat_epoch, run_an_eval_epoch
from affinity_module.utils import Collate
from affinity_module.dataset import VPLGDataset, FoldsOf_VPLGDataset

from affinity_module.protein_graph_loaders import DSSP_loader

from torch.backends import cudnn
# Out:
# Using backend: pytorch

# %% [markdown]
# ### Prepare parser & environment

# %%
cudnn.deterministic = True
cudnn.benchmark = False

args = get_config()
collate = Collate(args)
args['device'] = torch.device("cuda: 0") if torch.cuda.is_available() else torch.device("cpu")
set_random_seed(args['random_seed'])


argv_valFold = args['argv_valFold']
argv_testFold = args['argv_testFold']
cache_dir_prefix = args['cache_dir_prefix']

pdb2graph_translator = DSSP_loader(dssp_files_path = args['dssp_files_path'],
                                   includeAminoacidPhyschemFeatures = False,
                                   cache_dir_prefix = cache_dir_prefix)

best_model_filename = pdb2graph_translator.get_best_model_filename()

_colNames = dict(master_data_table = args['master_data_table'],
                 pdb_id_col_name="PDBs", smiles_col_name="SMILES", target_col_name="logKi",
                 foldId_col_name='Fold')

# %% [markdown]
# # Create & cache graphs

# %%
dataset = VPLGDataset(
    smiles_to_graph=args['smiles_to_graph'],
    smiles_node_featurizer=args['smiles_node_featurizer'],
    smiles_edge_featurizer=args['smiles_edge_featurizer'],
    **_colNames,
    pdb2graph_translator = pdb2graph_translator,
    load=False)
# Out:
# deleting old cache...
# graph_cache_dssp_noPCFAA/smiles_graphs: 10 deleted
# graph_cache_dssp_noPCFAA/fasta_graphs: 10 deleted
# graph_cache_dssp_noPCFAA/smiles: 10 deleted
# graph_cache_dssp_noPCFAA/labels: 10 deleted
# Processing dgl graphs from scratch...
# ...to load: 4514 4514 4514
# Processing graph 0/0
# Exception in pdbId_to_graph in line: 200, for SMILES; CCCCCC(=O)OC(CO)CO[PH](O)(O)OCC[N+](C)(C)C, PDB_ID: 4TNW
# ('4TNW', 7592, 'not in resnum2idx')
# Exception in pdbId_to_graph in line: 315, for SMILES; CCC(O)CC(=O)NC(CC(N)=O)C(=O)NC(CCC(N)=O)C(=O)NC(CO)CC(C)C, PDB_ID: 3KRD
# ('3KRD', 5868, 'not in resnum2idx')
# Processing graph 500/498
# Caching graph 499/499
# Processing graph 1000/998
# Caching graph 999/999
# Processing graph 1500/1498
# Caching graph 1499/1499
# Processing graph 2000/1998
# Caching graph 1999/1999
# Processing graph 2500/2498
# Caching graph 2499/2499
# Exception in pdbId_to_graph in line: 2698, for SMILES; CC(C#Cc1cccc(OC23CC4CC(CC(C4)C2)C3)c1)N([O])C(=N)O, PDB_ID: 3SHJ
# ('3SHJ', 6192, 'not in resnum2idx')
# Exception in pdbId_to_graph in line: 2699, for SMILES; CC(C)C1CCC(=O)NCCCCC(NC(=O)C(NC(=O)NC(C(=O)O)C(C)C)C(C)C)C(=O)N1, PDB_ID: 3GPJ
# ('3GPJ', 6192, 'not in resnum2idx')
# Exception in pdbId_to_graph in line: 2700, for SMILES; CC(C)CC(NC(=O)C(Cc1ccccc1)NC(=O)c1cnccn1)B(O)O, PDB_ID: 3MG0
# ('3MG0', 6219, 'not in resnum2idx')
# Exception in pdbId_to_graph in line: 2701, for SMILES; CCCCCCCC=CC=CC(=O)NC(C(=O)NC1C=CCCNC(=O)CCC(C(C)C)NC1=O)C(C)O, PDB_ID: 4GK7
# ('4GK7', 6398, 'not in resnum2idx')
# Exception in pdbId_to_graph in line: 2702, for SMILES; COc1ccc2c(c1)C(CC(=O)NC(C(=O)NC(CCc1ccccc1)C(=O)NCc1ccc(C)cc1)C(C)O)CC2=O, PDB_ID: 3MG6
# ('3MG6', 6187, 'not in resnum2idx')
# Exception in pdbId_to_graph in line: 2703, for SMILES; Cc1ccc(CNC(=O)C(CCc2ccccc2)NC(=O)C(CCc2ccccc2)NC(=O)C([NH3+])CCc2ccccc2)cc1, PDB_ID: 3MG4
# ('3MG4', 6192, 'not in resnum2idx')
# Processing graph 3000/2992
# Caching graph 2999/2999
# Exception in pdbId_to_graph in line: 3338, for SMILES; Brc1ccc(N2CCC[NH2+]CC2)cn1, PDB_ID: 4UM3
# ('4UM3', 7451, 'not in resnum2idx')
# Processing graph 3500/3491
# Caching graph 3499/3499
# Exception in pdbId_to_graph in line: 3530, for SMILES; CCCC(=O)C(=O)O, PDB_ID: 5TIG
# ('5TIG', 1771, 'not in resnum2idx')
# Processing graph 4000/3990
# Caching graph 3999/3999
# Processing graph 4500/4490
# Caching graph 4499/4499
# Caching graph 4504/4504
# smiles: 4504
# smiles_graphs: 4504
# fasta_graphs: 4504
# labels: 4504

# %% [markdown]
# ## Train the model

# %%
args['device'] = torch.device("cuda: 0") if torch.cuda.is_available() else torch.device("cpu")

raw_dataset = VPLGDataset(
    smiles_to_graph=args['smiles_to_graph'],
    smiles_node_featurizer=args['smiles_node_featurizer'],
    smiles_edge_featurizer=args['smiles_edge_featurizer'],
    **_colNames,
    pdb2graph_translator = pdb2graph_translator,
    load=True)


args['fasta_node_feat_size'] = raw_dataset.fasta_graphs[0].ndata['h'].shape[1]
args['fasta_edge_feat_size'] = raw_dataset.fasta_graphs[0].edata['e'].shape[1]
print(args['fasta_node_feat_size'], args['fasta_edge_feat_size'])

print('will save best model to:', best_model_filename)
shfl = True

p = dict(batch_size=args['batch_size'], shuffle=shfl, collate_fn=collate.collate_molgraphs)

mx_nodes = 5000 # filter out large graphs
folds5 = [0,1,2,3,4]
folds5.remove(argv_valFold)
if argv_testFold in folds5:
    folds5.remove(argv_testFold)
print('Folds to use: train=%s, val=%s, test=%s' % (str(folds5), str(argv_valFold), str(argv_testFold)) )
#
train_loader = FoldsOf_VPLGDataset(raw_dataset, folds5, max_nodes = mx_nodes).asDataLoader(**p)
val_loader =   FoldsOf_VPLGDataset(raw_dataset, [argv_valFold], max_nodes = mx_nodes ).asDataLoader(**p)
test_loader =  FoldsOf_VPLGDataset(raw_dataset, [argv_testFold], max_nodes = mx_nodes ).asDataLoader(**p)
print('number of batches: train %d, val %d, test %d' % (len(train_loader), len(val_loader), len(test_loader)))
    
torch.cuda.empty_cache()

model = load_model(args)
loss_fn = nn.MSELoss(reduction='none')

optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'],
                             weight_decay=args['weight_decay'])

stopper = EarlyStopping(mode=args['mode'],
                        patience=args['patience'],
                        filename=best_model_filename)

if args['load_checkpoint']:
    print('Loading checkpoint...')
    stopper.load_checkpoint(model)
model.to(args['device'])

for epoch in range(args['num_epochs']):
    # Train
    run_a_train_epoch(args, epoch, model, train_loader, loss_fn, optimizer)

    # Validation and early stop
    val_score_ext = run_stat_epoch(args, model, val_loader)
    val_score = val_score_ext[ args['metric_name'] ]
    
    test_score = run_an_eval_epoch(args, model, test_loader)
    early_stop = stopper.step(val_score, model)
    print('epoch {:d}/{:d}, validation {} {:.4f}, test {} {:.4f}, best validation {} {:.4f}'.format(
        epoch + 1, args['num_epochs'], args['metric_name'], val_score,
        args['metric_name'], test_score,
        args['metric_name'], stopper.best_score), 
          ', now R2 = %.4f' % val_score_ext['R2'])

    if early_stop:
        break

print('-'*80)
stopper.load_checkpoint(model)

print()

all_metrics = {}
for dsName, data_loader in zip(['train', 'val', 'test'], [train_loader, val_loader, test_loader]):    
    metrics, _, y_true, y_pred = run_stat_epoch(args, model, data_loader, return_pred=True)
    all_metrics[dsName] = (metrics, y_true, y_pred)


print('-'*50)


all_metric_names = set()
for dsName in ['train', 'val', 'test']:
    metrics, _, _ = all_metrics[dsName]
    for k in metrics.keys():
        all_metric_names.add(k)
#

print('%25s' % '', end='')
for dsName in ['train', 'val', 'test']:
    print('%12s' % dsName, end='')
print()
for mName in all_metric_names:
    print('%25s' % mName, end='')
    for dsName in ['train', 'val', 'test']:
        metrics, _, _ = all_metrics[dsName]
        print('%12.5f' % metrics[mName], end='')
    print()
#
print('-'*50)
# Out:
# Loading previously saved dgl graphs...
# smiles: 4504
# smiles_graphs: 4504
# fasta_graphs: 4504
# labels: 4504
# 32 6
# will save best model to: graph_cache_best_model_dssp_noPCFAA.pth
# Folds to use: train=[0, 1, 2, 3], val=4, test=4
# skip: len(fg.ndata['h']) == 5808
# skip: len(fg.ndata['h']) == 5616
# skip: len(fg.ndata['h']) == 5016
# skip: len(fg.ndata['h']) == 8384
# skip: len(fg.ndata['h']) == 6528
# skip: len(fg.ndata['h']) == 6224
# skip: len(fg.ndata['h']) == 6224
# skip: len(fg.ndata['h']) == 6818
# skip: len(fg.ndata['h']) == 6208
# skip: len(fg.ndata['h']) == 5891
# skip: len(fg.ndata['h']) == 5889
# skip: len(fg.ndata['h']) == 6173
# skip: len(fg.ndata['h']) == 6155
# skip: len(fg.ndata['h']) == 6162
# skip: len(fg.ndata['h']) == 6165
# skip: len(fg.ndata['h']) == 6178
# skip: len(fg.ndata['h']) == 6189
# skip: len(fg.ndata['h']) == 6173
# skip: len(fg.ndata['h']) == 7078
# skip: len(fg.ndata['h']) == 6148
# skip: len(fg.ndata['h']) == 6168
# skip: len(fg.ndata['h']) == 6173
# skip: len(fg.ndata['h']) == 7078
# skip: len(fg.ndata['h']) == 6148
# skip: len(fg.ndata['h']) == 6168
# number of batches: train 113, val 29, test 29
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple)
# epoch 1/1000, training mae 1.9223
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 1/1000, validation mae 1.4517, test mae 1.4526, best validation mae 1.4517 , now R2 = 0.1896
# epoch 2/1000, training mae 1.4391
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 2/1000, validation mae 1.5507, test mae 1.5514, best validation mae 1.4517 , now R2 = 0.1056
# epoch 3/1000, training mae 1.4115
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 3/1000, validation mae 1.4701, test mae 1.4701, best validation mae 1.4517 , now R2 = 0.1500
# epoch 4/1000, training mae 1.4062
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 4/1000, validation mae 1.3728, test mae 1.3736, best validation mae 1.3728 , now R2 = 0.2900
# epoch 5/1000, training mae 1.3777
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 5/1000, validation mae 1.4772, test mae 1.4798, best validation mae 1.3728 , now R2 = 0.1695
# epoch 6/1000, training mae 1.3669
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 6/1000, validation mae 1.4021, test mae 1.4035, best validation mae 1.3728 , now R2 = 0.2663
# epoch 7/1000, training mae 1.3794
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 7/1000, validation mae 1.3073, test mae 1.3066, best validation mae 1.3073 , now R2 = 0.3516
# epoch 8/1000, training mae 1.3568
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 8/1000, validation mae 1.4007, test mae 1.4028, best validation mae 1.3073 , now R2 = -0.2107
# epoch 9/1000, training mae 1.3449
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 9/1000, validation mae 1.3734, test mae 1.3729, best validation mae 1.3073 , now R2 = -0.0937
# epoch 10/1000, training mae 1.3435
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 10/1000, validation mae 1.4644, test mae 1.4638, best validation mae 1.3073 , now R2 = 0.1188
# epoch 11/1000, training mae 1.4004
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 11/1000, validation mae 1.3440, test mae 1.3438, best validation mae 1.3073 , now R2 = 0.3071
# epoch 12/1000, training mae 1.3479
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 12/1000, validation mae 1.3317, test mae 1.3314, best validation mae 1.3073 , now R2 = 0.3131
# epoch 13/1000, training mae 1.3723
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 13/1000, validation mae 1.3835, test mae 1.3827, best validation mae 1.3073 , now R2 = 0.2576
# epoch 14/1000, training mae 1.3431
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 7 out of 50
# epoch 14/1000, validation mae 1.4144, test mae 1.4123, best validation mae 1.3073 , now R2 = 0.2342
# epoch 15/1000, training mae 1.3379
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 8 out of 50
# epoch 15/1000, validation mae 1.3499, test mae 1.3487, best validation mae 1.3073 , now R2 = 0.2986
# epoch 16/1000, training mae 1.3045
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 9 out of 50
# epoch 16/1000, validation mae 1.3233, test mae 1.3255, best validation mae 1.3073 , now R2 = 0.2768
# epoch 17/1000, training mae 1.3160
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 10 out of 50
# epoch 17/1000, validation mae 1.3254, test mae 1.3271, best validation mae 1.3073 , now R2 = 0.3162
# epoch 18/1000, training mae 1.3058
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 11 out of 50
# epoch 18/1000, validation mae 1.3375, test mae 1.3375, best validation mae 1.3073 , now R2 = 0.0748
# epoch 19/1000, training mae 1.3128
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 12 out of 50
# epoch 19/1000, validation mae 1.3279, test mae 1.3241, best validation mae 1.3073 , now R2 = 0.3234
# epoch 20/1000, training mae 1.2981
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 20/1000, validation mae 1.2891, test mae 1.2876, best validation mae 1.2891 , now R2 = 0.3639
# epoch 21/1000, training mae 1.2948
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 21/1000, validation mae 1.3377, test mae 1.3369, best validation mae 1.2891 , now R2 = 0.3200
# epoch 22/1000, training mae 1.3171
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 22/1000, validation mae 1.3105, test mae 1.3112, best validation mae 1.2891 , now R2 = 0.3325
# epoch 23/1000, training mae 1.2820
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 23/1000, validation mae 1.2634, test mae 1.2626, best validation mae 1.2634 , now R2 = 0.3569
# epoch 24/1000, training mae 1.3353
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 24/1000, validation mae 1.3583, test mae 1.3586, best validation mae 1.2634 , now R2 = 0.2797
# epoch 25/1000, training mae 1.3407
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 25/1000, validation mae 1.3140, test mae 1.3158, best validation mae 1.2634 , now R2 = 0.3321
# epoch 26/1000, training mae 1.3319
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 26/1000, validation mae 1.2962, test mae 1.2947, best validation mae 1.2634 , now R2 = 0.3502
# epoch 27/1000, training mae 1.2981
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 27/1000, validation mae 1.3106, test mae 1.3096, best validation mae 1.2634 , now R2 = 0.3266
# epoch 28/1000, training mae 1.2865
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 28/1000, validation mae 1.3392, test mae 1.3398, best validation mae 1.2634 , now R2 = 0.3149
# epoch 29/1000, training mae 1.2709
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 29/1000, validation mae 1.3134, test mae 1.3142, best validation mae 1.2634 , now R2 = 0.3368
# epoch 30/1000, training mae 1.2575
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 7 out of 50
# epoch 30/1000, validation mae 1.3174, test mae 1.3180, best validation mae 1.2634 , now R2 = 0.3215
# epoch 31/1000, training mae 1.2781
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 31/1000, validation mae 1.2403, test mae 1.2409, best validation mae 1.2403 , now R2 = 0.3858
# epoch 32/1000, training mae 1.2490
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 32/1000, validation mae 1.2421, test mae 1.2416, best validation mae 1.2403 , now R2 = 0.3951
# epoch 33/1000, training mae 1.2500
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 33/1000, validation mae 1.2639, test mae 1.2653, best validation mae 1.2403 , now R2 = 0.3817
# epoch 34/1000, training mae 1.2477
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 34/1000, validation mae 1.3584, test mae 1.3587, best validation mae 1.2403 , now R2 = 0.2956
# epoch 35/1000, training mae 1.2437
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 35/1000, validation mae 1.2369, test mae 1.2307, best validation mae 1.2369 , now R2 = 0.4053
# epoch 36/1000, training mae 1.2317
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 36/1000, validation mae 1.2628, test mae 1.2620, best validation mae 1.2369 , now R2 = 0.3476
# epoch 37/1000, training mae 1.2413
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 37/1000, validation mae 1.2453, test mae 1.2514, best validation mae 1.2369 , now R2 = 0.3819
# epoch 38/1000, training mae 1.2241
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 38/1000, validation mae 1.2178, test mae 1.2173, best validation mae 1.2178 , now R2 = 0.4207
# epoch 39/1000, training mae 1.2294
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 39/1000, validation mae 1.2549, test mae 1.2547, best validation mae 1.2178 , now R2 = 0.3945
# epoch 40/1000, training mae 1.2347
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 40/1000, validation mae 1.2481, test mae 1.2482, best validation mae 1.2178 , now R2 = 0.3987
# epoch 41/1000, training mae 1.2111
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 41/1000, validation mae 1.2185, test mae 1.2187, best validation mae 1.2178 , now R2 = 0.4119
# epoch 42/1000, training mae 1.2050
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 42/1000, validation mae 1.2901, test mae 1.2904, best validation mae 1.2178 , now R2 = 0.3060
# epoch 43/1000, training mae 1.2062
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 43/1000, validation mae 1.2279, test mae 1.2290, best validation mae 1.2178 , now R2 = 0.4222
# epoch 44/1000, training mae 1.1948
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 44/1000, validation mae 1.1960, test mae 1.1973, best validation mae 1.1960 , now R2 = 0.4352
# epoch 45/1000, training mae 1.1738
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 45/1000, validation mae 1.2705, test mae 1.2741, best validation mae 1.1960 , now R2 = 0.3775
# epoch 46/1000, training mae 1.1822
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 46/1000, validation mae 1.2079, test mae 1.2080, best validation mae 1.1960 , now R2 = 0.4229
# epoch 47/1000, training mae 1.1673
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 47/1000, validation mae 1.1921, test mae 1.1921, best validation mae 1.1921 , now R2 = 0.4247
# epoch 48/1000, training mae 1.2047
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 48/1000, validation mae 1.2668, test mae 1.2664, best validation mae 1.1921 , now R2 = 0.3859
# epoch 49/1000, training mae 1.1899
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 49/1000, validation mae 1.2299, test mae 1.2298, best validation mae 1.1921 , now R2 = 0.4070
# epoch 50/1000, training mae 1.1583
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 50/1000, validation mae 1.2170, test mae 1.2168, best validation mae 1.1921 , now R2 = 0.4338
# epoch 51/1000, training mae 1.2758
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 51/1000, validation mae 1.3639, test mae 1.3644, best validation mae 1.1921 , now R2 = 0.2899
# epoch 52/1000, training mae 1.3285
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 52/1000, validation mae 1.2991, test mae 1.2981, best validation mae 1.1921 , now R2 = 0.3214
# epoch 53/1000, training mae 1.2987
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 53/1000, validation mae 1.3525, test mae 1.3509, best validation mae 1.1921 , now R2 = 0.2682
# epoch 54/1000, training mae 1.2804
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 7 out of 50
# epoch 54/1000, validation mae 1.2704, test mae 1.2735, best validation mae 1.1921 , now R2 = 0.3601
# epoch 55/1000, training mae 1.2349
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 8 out of 50
# epoch 55/1000, validation mae 1.2414, test mae 1.2404, best validation mae 1.1921 , now R2 = 0.3961
# epoch 56/1000, training mae 1.2133
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 9 out of 50
# epoch 56/1000, validation mae 1.2296, test mae 1.2302, best validation mae 1.1921 , now R2 = 0.4135
# epoch 57/1000, training mae 1.2054
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 10 out of 50
# epoch 57/1000, validation mae 1.1997, test mae 1.1990, best validation mae 1.1921 , now R2 = 0.4258
# epoch 58/1000, training mae 1.1810
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 58/1000, validation mae 1.1858, test mae 1.1869, best validation mae 1.1858 , now R2 = 0.4509
# epoch 59/1000, training mae 1.1721
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 59/1000, validation mae 1.3197, test mae 1.3192, best validation mae 1.1858 , now R2 = 0.3154
# epoch 60/1000, training mae 1.1837
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 60/1000, validation mae 1.1862, test mae 1.1875, best validation mae 1.1858 , now R2 = 0.4537
# epoch 61/1000, training mae 1.1663
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 61/1000, validation mae 1.2442, test mae 1.2449, best validation mae 1.1858 , now R2 = 0.3997
# epoch 62/1000, training mae 1.1571
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 62/1000, validation mae 1.2167, test mae 1.2199, best validation mae 1.1858 , now R2 = 0.4194
# epoch 63/1000, training mae 1.2783
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 63/1000, validation mae 1.4214, test mae 1.4198, best validation mae 1.1858 , now R2 = -3.1693
# epoch 64/1000, training mae 1.2140
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 64/1000, validation mae 1.2285, test mae 1.2248, best validation mae 1.1858 , now R2 = 0.4042
# epoch 65/1000, training mae 1.1939
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 7 out of 50
# epoch 65/1000, validation mae 1.1995, test mae 1.2003, best validation mae 1.1858 , now R2 = 0.4309
# epoch 66/1000, training mae 1.1634
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 8 out of 50
# epoch 66/1000, validation mae 1.2319, test mae 1.2337, best validation mae 1.1858 , now R2 = 0.4132
# epoch 67/1000, training mae 1.1571
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 9 out of 50
# epoch 67/1000, validation mae 1.2063, test mae 1.2093, best validation mae 1.1858 , now R2 = 0.4332
# epoch 68/1000, training mae 1.1536
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 68/1000, validation mae 1.1741, test mae 1.1720, best validation mae 1.1741 , now R2 = 0.4529
# epoch 69/1000, training mae 1.1842
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 69/1000, validation mae 1.2512, test mae 1.2507, best validation mae 1.1741 , now R2 = 0.3952
# epoch 70/1000, training mae 1.1532
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 70/1000, validation mae 1.1850, test mae 1.1847, best validation mae 1.1741 , now R2 = 0.4370
# epoch 71/1000, training mae 1.1320
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 71/1000, validation mae 1.1735, test mae 1.1730, best validation mae 1.1735 , now R2 = 0.4647
# epoch 72/1000, training mae 1.1185
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 72/1000, validation mae 1.1456, test mae 1.1447, best validation mae 1.1456 , now R2 = 0.4807
# epoch 73/1000, training mae 1.0866
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 73/1000, validation mae 1.1489, test mae 1.1487, best validation mae 1.1456 , now R2 = 0.4710
# epoch 74/1000, training mae 1.0794
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 74/1000, validation mae 1.1536, test mae 1.1540, best validation mae 1.1456 , now R2 = 0.4706
# epoch 75/1000, training mae 1.0712
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 75/1000, validation mae 1.1180, test mae 1.1174, best validation mae 1.1180 , now R2 = 0.5069
# epoch 76/1000, training mae 1.0812
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 76/1000, validation mae 1.1384, test mae 1.1414, best validation mae 1.1180 , now R2 = 0.4836
# epoch 77/1000, training mae 1.1075
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 77/1000, validation mae 1.2060, test mae 1.2069, best validation mae 1.1180 , now R2 = 0.4386
# epoch 78/1000, training mae 1.1124
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 78/1000, validation mae 1.1599, test mae 1.1603, best validation mae 1.1180 , now R2 = 0.4677
# epoch 79/1000, training mae 1.0747
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 79/1000, validation mae 1.1964, test mae 1.1978, best validation mae 1.1180 , now R2 = 0.4268
# epoch 80/1000, training mae 1.0775
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 80/1000, validation mae 1.2239, test mae 1.2255, best validation mae 1.1180 , now R2 = 0.3972
# epoch 81/1000, training mae 1.0733
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 81/1000, validation mae 1.1330, test mae 1.1330, best validation mae 1.1180 , now R2 = 0.4892
# epoch 82/1000, training mae 1.0539
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 82/1000, validation mae 1.1175, test mae 1.1183, best validation mae 1.1175 , now R2 = 0.4981
# epoch 83/1000, training mae 1.0402
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 83/1000, validation mae 1.1688, test mae 1.1701, best validation mae 1.1175 , now R2 = 0.4550
# epoch 84/1000, training mae 1.2415
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 84/1000, validation mae 1.2255, test mae 1.2253, best validation mae 1.1175 , now R2 = 0.4162
# epoch 85/1000, training mae 1.1910
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 85/1000, validation mae 1.2363, test mae 1.2375, best validation mae 1.1175 , now R2 = 0.4010
# epoch 86/1000, training mae 1.1740
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 86/1000, validation mae 1.1939, test mae 1.1906, best validation mae 1.1175 , now R2 = 0.4492
# epoch 87/1000, training mae 1.1545
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 87/1000, validation mae 1.2484, test mae 1.2486, best validation mae 1.1175 , now R2 = 0.3495
# epoch 88/1000, training mae 1.1558
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 88/1000, validation mae 1.1837, test mae 1.1841, best validation mae 1.1175 , now R2 = 0.4334
# epoch 89/1000, training mae 1.1303
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 7 out of 50
# epoch 89/1000, validation mae 1.2371, test mae 1.2375, best validation mae 1.1175 , now R2 = 0.3821
# epoch 90/1000, training mae 1.1322
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 8 out of 50
# epoch 90/1000, validation mae 1.1873, test mae 1.1868, best validation mae 1.1175 , now R2 = 0.4530
# epoch 91/1000, training mae 1.1196
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 9 out of 50
# epoch 91/1000, validation mae 1.1542, test mae 1.1536, best validation mae 1.1175 , now R2 = 0.4775
# epoch 92/1000, training mae 1.1285
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 10 out of 50
# epoch 92/1000, validation mae 1.1812, test mae 1.1794, best validation mae 1.1175 , now R2 = 0.4374
# epoch 93/1000, training mae 1.1002
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 11 out of 50
# epoch 93/1000, validation mae 1.1874, test mae 1.1879, best validation mae 1.1175 , now R2 = 0.4031
# epoch 94/1000, training mae 1.0921
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 12 out of 50
# epoch 94/1000, validation mae 1.1576, test mae 1.1579, best validation mae 1.1175 , now R2 = 0.4662
# epoch 95/1000, training mae 1.0803
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 13 out of 50
# epoch 95/1000, validation mae 1.1425, test mae 1.1445, best validation mae 1.1175 , now R2 = 0.4820
# epoch 96/1000, training mae 1.0652
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 14 out of 50
# epoch 96/1000, validation mae 1.1374, test mae 1.1379, best validation mae 1.1175 , now R2 = 0.4870
# epoch 97/1000, training mae 1.0484
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 15 out of 50
# epoch 97/1000, validation mae 1.1429, test mae 1.1455, best validation mae 1.1175 , now R2 = 0.4905
# epoch 98/1000, training mae 1.0558
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 16 out of 50
# epoch 98/1000, validation mae 1.1580, test mae 1.1577, best validation mae 1.1175 , now R2 = 0.4694
# epoch 99/1000, training mae 1.0393
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 17 out of 50
# epoch 99/1000, validation mae 1.1835, test mae 1.1842, best validation mae 1.1175 , now R2 = 0.4597
# epoch 100/1000, training mae 1.0660
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 18 out of 50
# epoch 100/1000, validation mae 1.1596, test mae 1.1592, best validation mae 1.1175 , now R2 = 0.4646
# epoch 101/1000, training mae 1.0423
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 19 out of 50
# epoch 101/1000, validation mae 1.1198, test mae 1.1214, best validation mae 1.1175 , now R2 = 0.4938
# epoch 102/1000, training mae 1.0259
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 20 out of 50
# epoch 102/1000, validation mae 1.1429, test mae 1.1436, best validation mae 1.1175 , now R2 = 0.4477
# epoch 103/1000, training mae 1.0233
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 21 out of 50
# epoch 103/1000, validation mae 1.1291, test mae 1.1290, best validation mae 1.1175 , now R2 = 0.4841
# epoch 104/1000, training mae 1.0077
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 104/1000, validation mae 1.1060, test mae 1.1091, best validation mae 1.1060 , now R2 = 0.5030
# epoch 105/1000, training mae 1.0302
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 105/1000, validation mae 1.1862, test mae 1.1863, best validation mae 1.1060 , now R2 = 0.4419
# epoch 106/1000, training mae 1.0412
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 106/1000, validation mae 1.1177, test mae 1.1192, best validation mae 1.1060 , now R2 = 0.5107
# epoch 107/1000, training mae 1.0038
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 107/1000, validation mae 1.1323, test mae 1.1340, best validation mae 1.1060 , now R2 = 0.4851
# epoch 108/1000, training mae 0.9948
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 108/1000, validation mae 1.0968, test mae 1.0961, best validation mae 1.0968 , now R2 = 0.5174
# epoch 109/1000, training mae 1.0004
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 109/1000, validation mae 1.1126, test mae 1.1113, best validation mae 1.0968 , now R2 = 0.5093
# epoch 110/1000, training mae 0.9732
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 110/1000, validation mae 1.0856, test mae 1.0843, best validation mae 1.0856 , now R2 = 0.5245
# epoch 111/1000, training mae 0.9708
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 111/1000, validation mae 1.0729, test mae 1.0736, best validation mae 1.0729 , now R2 = 0.5293
# epoch 112/1000, training mae 0.9740
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 112/1000, validation mae 1.0984, test mae 1.0988, best validation mae 1.0729 , now R2 = 0.5080
# epoch 113/1000, training mae 0.9869
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 113/1000, validation mae 1.1138, test mae 1.1160, best validation mae 1.0729 , now R2 = 0.5025
# epoch 114/1000, training mae 0.9626
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 114/1000, validation mae 1.1309, test mae 1.1326, best validation mae 1.0729 , now R2 = 0.4915
# epoch 115/1000, training mae 0.9484
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 115/1000, validation mae 1.0816, test mae 1.0811, best validation mae 1.0729 , now R2 = 0.5369
# epoch 116/1000, training mae 0.9262
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 116/1000, validation mae 1.0971, test mae 1.0996, best validation mae 1.0729 , now R2 = 0.5202
# epoch 117/1000, training mae 0.9431
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 117/1000, validation mae 1.1204, test mae 1.1216, best validation mae 1.0729 , now R2 = 0.5091
# epoch 118/1000, training mae 0.9677
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 7 out of 50
# epoch 118/1000, validation mae 1.1068, test mae 1.1072, best validation mae 1.0729 , now R2 = 0.5088
# epoch 119/1000, training mae 1.0121
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 8 out of 50
# epoch 119/1000, validation mae 1.1534, test mae 1.1536, best validation mae 1.0729 , now R2 = 0.4745
# epoch 120/1000, training mae 1.0069
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 9 out of 50
# epoch 120/1000, validation mae 1.0844, test mae 1.0838, best validation mae 1.0729 , now R2 = 0.5328
# epoch 121/1000, training mae 0.9482
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 10 out of 50
# epoch 121/1000, validation mae 1.1261, test mae 1.1264, best validation mae 1.0729 , now R2 = 0.4735
# epoch 122/1000, training mae 0.9722
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 11 out of 50
# epoch 122/1000, validation mae 1.1086, test mae 1.1078, best validation mae 1.0729 , now R2 = 0.5072
# epoch 123/1000, training mae 0.9820
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 12 out of 50
# epoch 123/1000, validation mae 1.1406, test mae 1.1375, best validation mae 1.0729 , now R2 = 0.4738
# epoch 124/1000, training mae 0.9683
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 13 out of 50
# epoch 124/1000, validation mae 1.0937, test mae 1.0939, best validation mae 1.0729 , now R2 = 0.5196
# epoch 125/1000, training mae 0.9272
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 14 out of 50
# epoch 125/1000, validation mae 1.0876, test mae 1.0880, best validation mae 1.0729 , now R2 = 0.5209
# epoch 126/1000, training mae 0.9391
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 15 out of 50
# epoch 126/1000, validation mae 1.1304, test mae 1.1312, best validation mae 1.0729 , now R2 = 0.4843
# epoch 127/1000, training mae 0.9367
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 127/1000, validation mae 1.0654, test mae 1.0652, best validation mae 1.0654 , now R2 = 0.5310
# epoch 128/1000, training mae 0.9200
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 128/1000, validation mae 1.0541, test mae 1.0542, best validation mae 1.0541 , now R2 = 0.5494
# epoch 129/1000, training mae 0.9385
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 129/1000, validation mae 1.1937, test mae 1.1933, best validation mae 1.0541 , now R2 = 0.4398
# epoch 130/1000, training mae 0.9423
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 130/1000, validation mae 1.2384, test mae 1.2385, best validation mae 1.0541 , now R2 = 0.4078
# epoch 131/1000, training mae 0.9099
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 131/1000, validation mae 1.0963, test mae 1.0958, best validation mae 1.0541 , now R2 = 0.5331
# epoch 132/1000, training mae 0.9106
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 132/1000, validation mae 1.0925, test mae 1.0919, best validation mae 1.0541 , now R2 = 0.5150
# epoch 133/1000, training mae 0.9051
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 133/1000, validation mae 1.1374, test mae 1.1334, best validation mae 1.0541 , now R2 = 0.4797
# epoch 134/1000, training mae 0.8890
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 134/1000, validation mae 1.0647, test mae 1.0634, best validation mae 1.0541 , now R2 = 0.5462
# epoch 135/1000, training mae 0.9097
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 7 out of 50
# epoch 135/1000, validation mae 1.0888, test mae 1.0881, best validation mae 1.0541 , now R2 = 0.5307
# epoch 136/1000, training mae 0.9132
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 8 out of 50
# epoch 136/1000, validation mae 1.0969, test mae 1.0966, best validation mae 1.0541 , now R2 = 0.5297
# epoch 137/1000, training mae 0.8863
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 9 out of 50
# epoch 137/1000, validation mae 1.0838, test mae 1.0842, best validation mae 1.0541 , now R2 = 0.5248
# epoch 138/1000, training mae 0.8590
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 10 out of 50
# epoch 138/1000, validation mae 1.0758, test mae 1.0757, best validation mae 1.0541 , now R2 = 0.5306
# epoch 139/1000, training mae 0.8653
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 11 out of 50
# epoch 139/1000, validation mae 1.1025, test mae 1.1027, best validation mae 1.0541 , now R2 = 0.4992
# epoch 140/1000, training mae 0.8690
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# epoch 140/1000, validation mae 1.0483, test mae 1.0468, best validation mae 1.0483 , now R2 = 0.5510
# epoch 141/1000, training mae 0.8527
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 1 out of 50
# epoch 141/1000, validation mae 1.1071, test mae 1.1071, best validation mae 1.0483 , now R2 = 0.4939
# epoch 142/1000, training mae 0.8640
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 2 out of 50
# epoch 142/1000, validation mae 1.0782, test mae 1.0789, best validation mae 1.0483 , now R2 = 0.5241
# epoch 143/1000, training mae 0.8593
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 3 out of 50
# epoch 143/1000, validation mae 1.0670, test mae 1.0670, best validation mae 1.0483 , now R2 = 0.5254
# epoch 144/1000, training mae 0.9942
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 4 out of 50
# epoch 144/1000, validation mae 1.1200, test mae 1.1199, best validation mae 1.0483 , now R2 = 0.4975
# epoch 145/1000, training mae 0.9224
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 5 out of 50
# epoch 145/1000, validation mae 1.1125, test mae 1.1127, best validation mae 1.0483 , now R2 = 0.4960
# epoch 146/1000, training mae 0.8967
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 6 out of 50
# epoch 146/1000, validation mae 1.1954, test mae 1.1945, best validation mae 1.0483 , now R2 = 0.4088
# epoch 147/1000, training mae 0.8917
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 7 out of 50
# epoch 147/1000, validation mae 1.0992, test mae 1.0997, best validation mae 1.0483 , now R2 = 0.5060
# epoch 148/1000, training mae 0.8576
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 8 out of 50
# epoch 148/1000, validation mae 1.1852, test mae 1.1888, best validation mae 1.0483 , now R2 = 0.4148
# epoch 149/1000, training mae 0.8518
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 9 out of 50
# epoch 149/1000, validation mae 1.1175, test mae 1.1183, best validation mae 1.0483 , now R2 = 0.4878
# epoch 150/1000, training mae 0.8516
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 10 out of 50
# epoch 150/1000, validation mae 1.1008, test mae 1.1009, best validation mae 1.0483 , now R2 = 0.5088
# epoch 151/1000, training mae 0.8483
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 11 out of 50
# epoch 151/1000, validation mae 1.1056, test mae 1.1025, best validation mae 1.0483 , now R2 = 0.4952
# epoch 152/1000, training mae 0.8070
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 12 out of 50
# epoch 152/1000, validation mae 1.1076, test mae 1.1083, best validation mae 1.0483 , now R2 = 0.5018
# epoch 153/1000, training mae 0.8119
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 13 out of 50
# epoch 153/1000, validation mae 1.0928, test mae 1.0911, best validation mae 1.0483 , now R2 = 0.5221
# epoch 154/1000, training mae 0.8058
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 14 out of 50
# epoch 154/1000, validation mae 1.1070, test mae 1.1083, best validation mae 1.0483 , now R2 = 0.4907
# epoch 155/1000, training mae 0.8230
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 15 out of 50
# epoch 155/1000, validation mae 1.0760, test mae 1.0738, best validation mae 1.0483 , now R2 = 0.5335
# epoch 156/1000, training mae 0.8068
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 16 out of 50
# epoch 156/1000, validation mae 1.1270, test mae 1.1271, best validation mae 1.0483 , now R2 = 0.4775
# epoch 157/1000, training mae 0.7790
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 17 out of 50
# epoch 157/1000, validation mae 1.1396, test mae 1.1412, best validation mae 1.0483 , now R2 = 0.4721
# epoch 158/1000, training mae 0.7838
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 18 out of 50
# epoch 158/1000, validation mae 1.1663, test mae 1.1661, best validation mae 1.0483 , now R2 = 0.4590
# epoch 159/1000, training mae 0.7602
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 19 out of 50
# epoch 159/1000, validation mae 1.1117, test mae 1.1090, best validation mae 1.0483 , now R2 = 0.4836
# epoch 160/1000, training mae 0.7655
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 20 out of 50
# epoch 160/1000, validation mae 1.0601, test mae 1.0598, best validation mae 1.0483 , now R2 = 0.5429
# epoch 161/1000, training mae 0.7631
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 21 out of 50
# epoch 161/1000, validation mae 1.1013, test mae 1.1016, best validation mae 1.0483 , now R2 = 0.5126
# epoch 162/1000, training mae 0.7544
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 22 out of 50
# epoch 162/1000, validation mae 1.1297, test mae 1.1327, best validation mae 1.0483 , now R2 = 0.4836
# epoch 163/1000, training mae 0.7302
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 23 out of 50
# epoch 163/1000, validation mae 1.1152, test mae 1.1148, best validation mae 1.0483 , now R2 = 0.5006
# epoch 164/1000, training mae 0.7340
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 24 out of 50
# epoch 164/1000, validation mae 1.0983, test mae 1.0984, best validation mae 1.0483 , now R2 = 0.5318
# epoch 165/1000, training mae 0.7451
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 25 out of 50
# epoch 165/1000, validation mae 1.1105, test mae 1.1110, best validation mae 1.0483 , now R2 = 0.5101
# epoch 166/1000, training mae 0.7459
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 26 out of 50
# epoch 166/1000, validation mae 1.1332, test mae 1.1296, best validation mae 1.0483 , now R2 = 0.4869
# epoch 167/1000, training mae 0.7405
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 27 out of 50
# epoch 167/1000, validation mae 1.1511, test mae 1.1506, best validation mae 1.0483 , now R2 = 0.4583
# epoch 168/1000, training mae 0.7376
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 28 out of 50
# epoch 168/1000, validation mae 1.1587, test mae 1.1589, best validation mae 1.0483 , now R2 = 0.4641
# epoch 169/1000, training mae 0.7190
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 29 out of 50
# epoch 169/1000, validation mae 1.0720, test mae 1.0719, best validation mae 1.0483 , now R2 = 0.5434
# epoch 170/1000, training mae 0.7188
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 30 out of 50
# epoch 170/1000, validation mae 1.0962, test mae 1.0950, best validation mae 1.0483 , now R2 = 0.5191
# epoch 171/1000, training mae 0.7478
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 31 out of 50
# epoch 171/1000, validation mae 1.1368, test mae 1.1383, best validation mae 1.0483 , now R2 = 0.4730
# epoch 172/1000, training mae 0.7244
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 32 out of 50
# epoch 172/1000, validation mae 1.1165, test mae 1.1152, best validation mae 1.0483 , now R2 = 0.5091
# epoch 173/1000, training mae 0.7271
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 33 out of 50
# epoch 173/1000, validation mae 1.1370, test mae 1.1363, best validation mae 1.0483 , now R2 = 0.4765
# epoch 174/1000, training mae 0.7246
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 34 out of 50
# epoch 174/1000, validation mae 1.0965, test mae 1.0974, best validation mae 1.0483 , now R2 = 0.4987
# epoch 175/1000, training mae 0.7133
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 35 out of 50
# epoch 175/1000, validation mae 1.0808, test mae 1.0783, best validation mae 1.0483 , now R2 = 0.5239
# epoch 176/1000, training mae 0.7142
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 36 out of 50
# epoch 176/1000, validation mae 1.1414, test mae 1.1411, best validation mae 1.0483 , now R2 = 0.4874
# epoch 177/1000, training mae 0.7259
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 37 out of 50
# epoch 177/1000, validation mae 1.0810, test mae 1.0822, best validation mae 1.0483 , now R2 = 0.5369
# epoch 178/1000, training mae 0.6892
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 38 out of 50
# epoch 178/1000, validation mae 1.2624, test mae 1.2622, best validation mae 1.0483 , now R2 = 0.3811
# epoch 179/1000, training mae 0.6734
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 39 out of 50
# epoch 179/1000, validation mae 1.0758, test mae 1.0767, best validation mae 1.0483 , now R2 = 0.5292
# epoch 180/1000, training mae 0.7086
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 40 out of 50
# epoch 180/1000, validation mae 1.1218, test mae 1.1217, best validation mae 1.0483 , now R2 = 0.4843
# epoch 181/1000, training mae 0.7222
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 41 out of 50
# epoch 181/1000, validation mae 1.0949, test mae 1.0947, best validation mae 1.0483 , now R2 = 0.5291
# epoch 182/1000, training mae 0.7034
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 42 out of 50
# epoch 182/1000, validation mae 1.1005, test mae 1.1015, best validation mae 1.0483 , now R2 = 0.5127
# epoch 183/1000, training mae 0.6895
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 43 out of 50
# epoch 183/1000, validation mae 1.0726, test mae 1.0733, best validation mae 1.0483 , now R2 = 0.5316
# epoch 184/1000, training mae 0.6618
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 44 out of 50
# epoch 184/1000, validation mae 1.1254, test mae 1.1259, best validation mae 1.0483 , now R2 = 0.4891
# epoch 185/1000, training mae 0.6734
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 45 out of 50
# epoch 185/1000, validation mae 1.1408, test mae 1.1413, best validation mae 1.0483 , now R2 = 0.4592
# epoch 186/1000, training mae 0.6696
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 46 out of 50
# epoch 186/1000, validation mae 1.1345, test mae 1.1336, best validation mae 1.0483 , now R2 = 0.4767
# epoch 187/1000, training mae 0.6640
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 47 out of 50
# epoch 187/1000, validation mae 1.0920, test mae 1.0935, best validation mae 1.0483 , now R2 = 0.5243
# epoch 188/1000, training mae 0.6559
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 48 out of 50
# epoch 188/1000, validation mae 1.0966, test mae 1.0942, best validation mae 1.0483 , now R2 = 0.5210
# epoch 189/1000, training mae 0.6431
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 49 out of 50
# epoch 189/1000, validation mae 1.0876, test mae 1.0868, best validation mae 1.0483 , now R2 = 0.5311
# epoch 190/1000, training mae 0.6422
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_an_eval_epoch] will ignore batch 28 with size 1
# EarlyStopping counter: 50 out of 50
# epoch 190/1000, validation mae 1.1560, test mae 1.1533, best validation mae 1.0483 , now R2 = 0.4651
# --------------------------------------------------------------------------------
#
#   [run_stat_epoch] will ignore batch 28 with size 1
#   [run_stat_epoch] will ignore batch 28 with size 1
# --------------------------------------------------
#                                 train         val        test
#     median_absolute_error     0.59363     0.82347     0.82347
#                       mae     0.73022     1.04897     1.04838
#                 max_error     5.01071     5.10689     5.10689
#                       mse     0.89278     1.86921     1.86877
#                        R2     0.79039     0.55083     0.55102
# --------------------------------------------------

# %%
_baseFname = pdb2graph_translator.get_best_model_filename().replace('.pth', '')

for dsName in ['train', 'val', 'test']:
    _, y_true, y_pred = all_metrics[dsName]
    y_true = np.array(y_true)[:, 0]
    y_pred = np.array(y_pred)

    np.savetxt(_baseFname+'_yy_%s.txt' % dsName, np.vstack((y_true, y_pred)).T, 
               header='y_true, y_pred (%s)' % dsName )
